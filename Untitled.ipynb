# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df=pd.read_csv('all.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'District', 'Persons', 'Males', 'Females',
#        'Growth..1991...2001.', 'Rural', 'Urban', 'Scheduled.Caste.population',
#        'Percentage...SC.to.total', 'Number.of.households',
#        'Household.size..per.household.', 'Sex.ratio..females.per.1000.males.',
#        'Sex.ratio..0.6.years.', 'Scheduled.Tribe.population',
#        'Percentage.to.total.population..ST.', 'Persons..literate',
#        'Males..Literate', 'Females..Literate', 'Persons..literacy.rate',
#        'Males..Literatacy.Rate', 'Females..Literacy.Rate', 'Total.Educated',
#        'Data.without.level', 'Below.Primary', 'Primary', 'Middle',
#        'Matric.Higher.Secondary.Diploma', 'Graduate.and.Above', 'X0...4.years',
#        'X5...14.years', 'X15...59.years', 'X60.years.and.above..Incl..A.N.S..',
#        'Total.workers', 'Main.workers', 'Marginal.workers', 'Non.workers',
#        'SC.1.Name', 'SC.1.Population', 'SC.2.Name', 'SC.2.Population',
# ...

# %%
df=df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#     State                                           District  Persons  \
# 0      AN  District Andamans (01), Andaman & Nicobar Isla...   314084
# 1      AN  District Nicobars (02), Andaman & Nicobar Isla...    42068
# 2  Andhra        District Adilabad (01), Andhra Pradesh (28)  2488003
# 3  Andhra       District Nizamabad (02), Andhra Pradesh (28)  2345685
# 4  Andhra      District Karimnagar (03), Andhra Pradesh (28)  3491822
#
#      Males  Females Growth..1991...2001.    Rural   Urban  \
# 0   170319   143765                30.14   197886  116198
# 1    22653    19415                 7.19    42068       -
# 2  1250958  1237045                19.06  1827986     NaN
# 3  1162905  1182780                14.98  1920947     NaN
# 4  1747968  1743854                14.47  2813010     NaN
#
#   Scheduled.Caste.population Percentage...SC.to.total  ...  Medical.facility  \
# 0                          -                        -  ...               102
# ...

# %%
df=df.groupby(["State"]).sum()
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22712\2900096921.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df=df.groupby(["State"]).sum()
#                     Persons     Males   Females  Number.of.households  \
# State
# AN                   356152    192972    163180               78242.0
# Andhra             71308587  36067773  35240814            15801644.0
# ArunachalPradesh    1097968    579941    518027              215574.0
# Assam              26655528  13777037  12878491             4914823.0
# Bihar              82998509  43243795  39754714            13744130.0
# CG                 20833803  10474218  10359585             4091551.0
# Chandigarh           900635    506938    393697              206465.0
# D_D                  158204     92512     65692               35686.0
# ...

# %%
df1=pd.read_csv("all.csv")
unique_values = df1['State'].unique()
unique_values
# Out:
# array(['AN', 'Andhra', 'ArunachalPradesh', 'Assam', 'Bihar', 'CG',
#        'Chandigarh', 'D_D', 'Delhi', 'D_N_H', 'Goa', 'Gujarat', 'Haryana',
#        'HP', 'Jharkhand', 'JK', 'Karnataka', 'Kerala', 'Lakshdweep',
#        'Maharashtra', 'Manipur', 'Meghalya', 'Mizoram', 'MP', 'Nagaland',
#        'Orrisa', 'Pondicherry', 'Punjab', 'Rajasthan', 'Sikkim', 'TN',
#        'Tripura', 'UP', 'Uttranchal', 'WB'], dtype=object)

# %%
df['State'] = unique_values

# %%
null_values:list=['?',' ','',-999,-9999,'-','AN']                                    # null values marks
for null_value in null_values:                                                  #
  print(f'Value count for null type "{null_value}" is :',(df==null_value).sum().sum())
# Out:
# Value count for null type "?" is : 0
# Value count for null type " " is : 0
# Value count for null type "" is : 0
# Value count for null type "-999" is : 0
# Value count for null type "-9999" is : 0
# Value count for null type "-" is : 0
# Value count for null type "AN" is : 0

# %%
(df=="-").sum()
# Out:
# Persons                                   0
# Males                                     0
# Females                                   0
# Number.of.households                      0
# Household.size..per.household.            0
# Sex.ratio..females.per.1000.males.        0
# Sex.ratio..0.6.years.                     0
# Persons..literate                         0
# Males..Literate                           0
# Females..Literate                         0
# Persons..literacy.rate                    0
# Males..Literatacy.Rate                    0
# Females..Literacy.Rate                    0
# Total.Educated                            0
# Data.without.level                        0
# Below.Primary                             0
# Primary                                   0
# Middle                                    0
# Matric.Higher.Secondary.Diploma           0
# Graduate.and.Above                        0
# X0...4.years                              0
# ...

# %%
df.replace(to_replace="AN",value=0,inplace=True)

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df["Persons"], bins=20, kde=True, color='blue');

# %%
corr=df.corr()
print((corr))
# Out:
#                                          Persons     Males   Females  \
# Persons                                 1.000000  0.999783  0.999743
# Males                                   0.999783  1.000000  0.999054
# Females                                 0.999743  0.999054  1.000000
# Number.of.households                    0.984248  0.981148  0.987135
# Household.size..per.household.          0.894553  0.898963  0.889313
# Sex.ratio..females.per.1000.males.      0.913933  0.914409  0.912964
# Sex.ratio..0.6.years.                   0.913315  0.914342  0.911748
# Persons..literate                       0.974798  0.972267  0.977071
# Males..Literate                         0.987960  0.986592  0.988961
# Females..Literate                       0.942430  0.938132  0.946642
# Persons..literacy.rate                  0.900380  0.900213  0.900117
# Males..Literatacy.Rate                  0.905772  0.906181  0.904880
# Females..Literacy.Rate                  0.879487  0.878097  0.880566
# ...

# %%
plt.show();

# %%
plt.scatter(df["State"],df["Persons"]);
plt.xticks(rotation=90)
plt.figure(figsize=(100,100))
plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))
x=df['State'] 
y=df["Females..Literacy.Rate"]
plt.plot(x,y, marker='o', label='Female')
plt.xlabel('State')
plt.ylabel('Literacy Rate ')
plt.title('Comparison of Male and Female Literacy  Over Time')
plt.legend()
plt.xticks(rotation=90)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
x=df['State'] 
y=df['Persons..literate']
plt.plot(x,y, marker='o')
plt.xlabel('State')
plt.ylabel('Total Number')
plt.title('Comparison of Female Literacy Rates Over Time')
plt.legend()
plt.xticks(rotation=90)

plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(df["Persons"])
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(8, 6))
plt.bar(df["State"], df["Permanent.House"])
plt.bar(df["State"], df["Semi.permanent.House"])
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('School Archit')
plt.xticks(rotation=90)

plt.show();

# %%
 df = df.dropna(axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, AN to WB
# Data columns (total 47 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Persons                                 35 non-null     int64
#  1   Males                                   35 non-null     int64
#  2   Females                                 35 non-null     int64
#  3   Number.of.households                    35 non-null     float64
#  4   Household.size..per.household.          35 non-null     float64
#  5   Sex.ratio..females.per.1000.males.      35 non-null     float64
#  6   Sex.ratio..0.6.years.                   35 non-null     float64
#  7   Persons..literate                       35 non-null     int64
#  8   Males..Literate                         35 non-null     int64
#  9   Females..Literate                       35 non-null     int64
# ...

# %%
df["SC.1.Population"]
# Out:
# State
# AN                           -
# Andhra               6768865.0
# ArunachalPradesh        2563.0
# Assam                 825554.0
# Bihar                5682349.0
# CG                   1705308.0
# Chandigarh             68666.0
# D_D                     3924.0
# D_N_H                   1554.0
# Delhi                 907823.0
# Goa                    13570.0
# Gujarat              1816012.0
# HP                    727971.0
# Haryana              2079132.0
# JK                    350270.0
# Jharkhand            1080875.0
# Karnataka            3513684.0
# Kerala               1331693.0
# Lakshdweep                   -
# MP                   5107970.0
# Maharashtra          5721239.0
# Manipur                51792.0
# Meghalya                3706.0
# Mizoram                  120.0
# Nagaland                     -
# Orrisa               2455566.0
# Pondicherry           138190.0
# Punjab               4178110.0
# Rajasthan            4489340.0
# Sikkim                 17950.0
# ...

# %%
hind=np.sum(df["Religeon.1.Population"])
muslim=np.sum(df["Religeon.2.Population"])
other=np.sum(df["Religeon.3.Population"])

# %%
religion=np.array([hind,muslim,other])
labels=["Hindu","Muslim","others"]

# %%
plt.pie(religion,labels=labels);

# %%
plt.figure(figsize=(10, 6))
x=df['State'] 
y=df["Electricity..Power.Supply."]
plt.plot(x,y, marker='o', label='No of House ')
plt.xlabel('State')
plt.ylabel('No of House ')
plt.title('Electricity in every State')
plt.legend()
plt.xticks(rotation=90)

plt.grid(True)
plt.show()

# %%
plt.bar(df["State"], df["Household.size..per.household."])
plt.xticks(rotation=90);
plt.ylabel("Household")
plt.show();

# %%
plt.bar(df["State"],df["Total.Educated"])
plt.xticks(rotation=90);
plt.ylabel("EDuacted")
plt.show();

# %%
below=np.sum(df["Below.Primary"])
primary=np.sum(df["Primary"])
middle=np.sum(df["Middle"])
print(df.columns)
# Out:
# Index(['Persons', 'Males', 'Females', 'Number.of.households',
#        'Household.size..per.household.', 'Sex.ratio..females.per.1000.males.',
#        'Sex.ratio..0.6.years.', 'Persons..literate', 'Males..Literate',
#        'Females..Literate', 'Persons..literacy.rate', 'Males..Literatacy.Rate',
#        'Females..Literacy.Rate', 'Total.Educated', 'Data.without.level',
#        'Below.Primary', 'Primary', 'Middle', 'Matric.Higher.Secondary.Diploma',
#        'Graduate.and.Above', 'X0...4.years', 'X5...14.years', 'X15...59.years',
#        'X60.years.and.above..Incl..A.N.S..', 'Total.workers', 'Main.workers',
#        'Marginal.workers', 'Non.workers', 'SC.1.Population', 'SC.2.Population',
#        'SC.3.Population', 'Religeon.1.Population', 'Religeon.2.Population',
#        'Religeon.3.Population', 'Imp.Town.1.Population',
#        'Imp.Town.2.Population', 'Imp.Town.3.Population',
#        'Total.Inhabited.Villages', 'Drinking.water.facilities',
# ...

# %%
df_drop=df.drop(['State'],axis=1)
sns.heatmap(df_drop,vmin=0,vmax=1)
# Out:
# <Axes: ylabel='State'>

# %%
df["State"]
# Out:
# State
# AN                                 0
# Andhra                        Andhra
# ArunachalPradesh    ArunachalPradesh
# Assam                          Assam
# Bihar                          Bihar
# CG                                CG
# Chandigarh                Chandigarh
# D_D                              D_D
# D_N_H                          Delhi
# Delhi                          D_N_H
# Goa                              Goa
# Gujarat                      Gujarat
# HP                           Haryana
# Haryana                           HP
# JK                         Jharkhand
# Jharkhand                         JK
# Karnataka                  Karnataka
# Kerala                        Kerala
# Lakshdweep                Lakshdweep
# MP                       Maharashtra
# Maharashtra                  Manipur
# Manipur                     Meghalya
# Meghalya                     Mizoram
# Mizoram                           MP
# Nagaland                    Nagaland
# ...
